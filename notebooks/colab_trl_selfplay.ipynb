# %% [markdown]
# # Cyber Self-Play TRL (Colab)
#
# Minimal PFSP-based self-play loop scaffold for the `cyber_selfplay` OpenEnv project.

# %%
# !pip install "openenv-core[core]" "trl>=0.10.0" "transformers>=4.40.0" datasets accelerate peft

# %%
import sys
from pathlib import Path

repo_root = Path('/content')
if (repo_root / 'cyber_selfplay').exists():
    sys.path.append(str(repo_root / 'cyber_selfplay'))

# !python train/colab_trl_selfplay.py
