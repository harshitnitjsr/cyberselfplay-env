# %%
# =============================================================================
# CyberSelfPlay — Kaggle: SFT + League (PFSP/PSRO) + GRPO  (full merge, single cell)
#
#   Phase 1: same SFT as kaggle_grpo.py
#   Phase 2: for each league round (LEAGUE_ROUNDS):
#       • PFSP sample Red archetype (R-easy / R-mid / R-hard) from a pool
#       • build GRPO prompts with that Red’s rollout (exploit count range)
#       • compute_rewards uses the SAME profile (aligned env preamble)
#       • mini-GRPO: GRPO_STEPS_PER_ROUND steps, same LoRA
#       • update pool win-rates; PSRO: replicator on heuristic-eval payoffs
#
# Slower than kaggle_grpo.py — reduce LEAGUE_ROUNDS or GRPO_STEPS_PER_ROUND.
# If train.pfsp import fails, fallbacks are inlined.
# =============================================================================

# ---------- 1) Install Unsloth + TRL + OpenEnv deps ----------
get_ipython().system('pip install -q "unsloth[colab-new] @ git+https://github.com/unslothai/unsloth.git"')
get_ipython().system('pip install -q --upgrade git+https://github.com/huggingface/trl.git')
get_ipython().system('pip install -q sympy scipy fastapi uvicorn datasets pydantic openenv-core huggingface_hub matplotlib')

# ---------- 2) Clone your deployed Hugging Face Space (edit URL if you fork) ----------
import os, sys, shutil
HF_SPACE_CLONE = os.environ.get(
    "HF_SPACE_CLONE",
    "https://huggingface.co/spaces/HarshitShri026/cyberselfplay-env",
)
os.chdir("/content")
shutil.rmtree("/content/cyberselfplay-env", ignore_errors=True)
get_ipython().system("git clone " + HF_SPACE_CLONE)
os.chdir("/content/cyberselfplay-env")
sys.path.insert(0, "/content/cyberselfplay-env")
get_ipython().system("pip install -q -e .")

# ---------- 3) Wipe any prior checkpoint ----------
shutil.rmtree("/content/cyberselfplay-env/outputs_cyber", ignore_errors=True)

# ---------- 4) Silence noisy warnings ----------
import warnings, logging
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=UserWarning)
logging.getLogger("transformers").setLevel(logging.ERROR)
logging.getLogger("trl").setLevel(logging.WARNING)

# ---------- 5) Imports (Unsloth FIRST) ----------
import unsloth
import torch, json, random, re
from pathlib import Path
from datasets import Dataset
from unsloth import FastLanguageModel
from trl import SFTTrainer, SFTConfig, GRPOConfig, GRPOTrainer

from cyber_selfplay_env.environment import CyberSelfPlayEnvironment
from cyber_selfplay_env.models import CyberAction
from cyber_selfplay_env.tools_blue import BLUE_TOOLS

try:
    from train.pfsp import OpponentStats, sample_opponent, pfsp_weight
    from train.psro_meta import replicator_update, normalize as psro_normalize
except Exception:  # noqa: BLE001
    from dataclasses import dataclass

    @dataclass
    class OpponentStats:
        name: str
        win_rate_vs_learner: float
        games: int = 0

    def pfsp_weight(w: float) -> float:
        w = min(1.0, max(0.0, w))
        return w * (1.0 - w)

    def sample_opponent(opponents):
        pool = list(opponents)
        weights = [pfsp_weight(o.win_rate_vs_learner) for o in pool]
        t = sum(weights)
        if t <= 0:
            return random.choice(pool)
        return random.choices(pool, weights=weights, k=1)[0]

    def psro_normalize(xs):
        s = sum(max(0.0, x) for x in xs)
        if s <= 0:
            return [1.0 / len(xs)] * len(xs)
        return [max(0.0, x) / s for x in xs]

    def replicator_update(payoff_row, current, eta=0.2):
        u_bar = sum(p * u for p, u in zip(current, payoff_row))
        nxt = [p * (1.0 + eta * (u - u_bar)) for p, u in zip(current, payoff_row)]
        return psro_normalize(nxt)

# ---------- 6) Env vars ----------
os.environ["TRANSFORMERS_VERBOSITY"]    = "error"
os.environ["TOKENIZERS_PARALLELISM"]    = "false"
os.environ["HF_HUB_ENABLE_HF_TRANSFER"] = "1"
os.environ["WANDB_DISABLED"]            = "true"
os.environ["BITSANDBYTES_NOWELCOME"]    = "1"
if torch.cuda.device_count() > 1:
    os.environ["CUDA_VISIBLE_DEVICES"] = "0"
    print("Kaggle T4 x2 detected -- using GPU 0 only (Unsloth single-GPU).")

# ---------- 7) Precision ----------
has_cuda = torch.cuda.is_available()
use_bf16 = has_cuda and torch.cuda.is_bf16_supported()
use_fp16 = has_cuda and not use_bf16
print(f"CUDA: {has_cuda} | bf16: {use_bf16} | fp16: {use_fp16}")
print(f"GPU: {torch.cuda.get_device_name(0) if has_cuda else 'none'}")

# ---------- 8) Model load ----------
MAX_SEQ_LEN = 1024
LORA_RANK   = 16
BASE_MODEL  = "unsloth/Qwen2.5-Coder-1.5B-Instruct-bnb-4bit"

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name=BASE_MODEL,
    max_seq_length=MAX_SEQ_LEN,
    dtype=None,
    load_in_4bit=True,
)
tokenizer.model_max_length = MAX_SEQ_LEN
if tokenizer.pad_token is None:
    tokenizer.pad_token = tokenizer.eos_token

model = FastLanguageModel.get_peft_model(
    model,
    r=LORA_RANK,
    target_modules=["q_proj","k_proj","v_proj","o_proj","gate_proj","up_proj","down_proj"],
    lora_alpha=LORA_RANK,
    use_gradient_checkpointing="unsloth",
)

# Clear `generation_config.max_length` so it does NOT collide with `max_new_tokens`
# at every `model.generate(...)` call (silences the spammy transformers warning).
if getattr(model, "generation_config", None) is not None:
    model.generation_config.max_length = None
    model.generation_config.max_new_tokens = None

IS_LLAMA = "llama" in BASE_MODEL.lower()
IS_QWEN  = "qwen"  in BASE_MODEL.lower()

# ---------- 9) Prompt builder (single source of truth) + JSON parser ----------
# Both SFT data and GRPO inference go through tokenizer.apply_chat_template
# so the formats are byte-identical. NO hand-written prompt strings anywhere.
VALID_BLUE = list(BLUE_TOOLS)

SYSTEM_MSG = (
    "You are the Blue defender in a cyber self-play game.\n"
    "You MUST output ONLY a valid JSON object.\n"
    "No explanation. No extra text. No prefixes/suffixes.\n"
    "Output exactly ONE JSON object and stop.\n\n"
    f"Schema: {{\"actor\":\"blue\",\"tool_name\":<one of {sorted(VALID_BLUE)}>,"
    "\"target\":\"host-XX\",\"params\":{},\"rationale\":\"short\"}}"
)

def _user_msg(obs_dict: dict) -> str:
    return (
        f"Observation:\n{json.dumps(obs_dict, ensure_ascii=True)}\n\n"
        "Reply with ONE JSON line ending with '}'. Nothing else."
    )

def obs_to_prompt(obs_dict: dict) -> str:
    """Inference prompt. Same chat template SFT used, with assistant header appended."""
    return tokenizer.apply_chat_template(
        [
            {"role": "system", "content": SYSTEM_MSG},
            {"role": "user",   "content": _user_msg(obs_dict)},
        ],
        tokenize=False,
        add_generation_prompt=True,
    )

# JSON_RE = re.compile(r"\{[^{}]*\}", re.DOTALL)

JSON_RE = re.compile(r"\{.*\}", re.DOTALL)

def parse_action(text: str):
    matches = JSON_RE.findall(text)
    if not matches:
        return None, False

    for m in matches:
        try:
            a = json.loads(m)
            if a.get("tool_name") in VALID_BLUE:
                a["actor"] = "blue"
                a.setdefault("target", "host-00")
                a.setdefault("params", {})
                a.setdefault("rationale", "grpo")
                return a, True
        except:
            continue

    return None, False

# =============================================================================
# PHASE 1 -- SFT warm-start (imitate heuristic Blue policy)
# =============================================================================

# ---------- 10) Heuristic Blue policy (lifted from train/colab_trl_selfplay.py) ----------
# Real catalog of `required_tool` values used by the env's instruction system
# (see cyber_selfplay_env/simulator.py::_build_instructions). Picking from this
# list means execute_instruction has a real chance (1/8) of matching.
INSTRUCTION_TOOLS = [
    "triage_alerts", "isolate_host", "deploy_patch", "rotate_secrets",
    "run_forensics", "restore_backup", "harden_policy", "publish_ioc_blocklist",
]

RATIONALE = {
    "query_siem":            "scan telemetry",
    "triage_alerts":         "investigate alert",
    "isolate_host":          "contain breach",
    "disable_account":       "lock compromised user",
    "rotate_secrets":        "remove persistence",
    "deploy_patch":          "harden vulnerable host",
    "harden_policy":         "tighten controls",
    "restore_backup":        "recover service",
    "run_forensics":         "investigate host",
    "publish_ioc_blocklist": "block known IOCs",
    "execute_instruction":   "follow playbook",
    "checkpoint_plan":       "track progress",
    "reconcile_state":       "stabilize state",
}

EPSILON_RANDOM = 0.40  # 40% pure exploration in SFT data => corpus covers all
                       # 13 tools roughly evenly, killing the "default action"
                       # bias that triggers post-SFT mode collapse.

def heuristic_blue_action(public_state: dict, telemetry: list, t_step: int) -> dict:
    """State-conditional, diverse Blue policy.

    The previous version only ever fired ~3 branches and ~80% of the data
    became `execute_instruction`, which caused SFT mode collapse. This version
    builds a *weighted candidate set* from the current observation and samples
    one, plus a 20% epsilon-random arm. Result: the SFT corpus exercises all
    13 Blue tools with realistic targets, so the model learns the schema
    BROADLY and GRPO has real diversity to do credit assignment on.
    """
    detections = telemetry or public_state.get("detections", []) or []
    known      = int(public_state.get("known_incident_count", 0) or 0)
    instr      = public_state.get("instruction_progress", {}) or {}
    instr_pending = isinstance(instr, dict) and instr.get("completed", 0) < instr.get("total", 1)

    rand_host = lambda: f"host-{random.randint(0, 5):02d}"

    # 20% pure exploration: random valid tool with a syntactically correct payload.
    if random.random() < EPSILON_RANDOM:
        tool = random.choice(VALID_BLUE)
        if tool == "execute_instruction":
            target, params = "", {"required_tool": random.choice(INSTRUCTION_TOOLS)}
        elif tool == "disable_account":
            target, params = f"user-{random.randint(0, 3):02d}", {}
        else:
            target, params = rand_host(), {}
        return {"actor": "blue", "tool_name": tool, "target": target,
                "params": params, "rationale": RATIONALE.get(tool, "explore")}

    # Build (tool, target, params, weight) candidates from the observation.
    cands: list[tuple[str, str, dict, int]] = []

    # Always-valid baseline (covers tools that always parse but pay little).
    cands += [
        ("query_siem",       rand_host(), {}, 1),
        ("checkpoint_plan",  rand_host(), {}, 1),
        ("reconcile_state",  rand_host(), {}, 1),
        ("deploy_patch",     rand_host(), {}, 1),
        ("harden_policy",    rand_host(), {}, 1),
        ("publish_ioc_blocklist", rand_host(), {}, 1),
        ("disable_account",  f"user-{random.randint(0, 3):02d}", {}, 1),
    ]

    if detections:
        cands += [("triage_alerts", rand_host(), {}, 3)]   # +2.0 reward when valid

    if known > 0:
        cands += [
            ("isolate_host",   rand_host(), {}, 3),         # +3.0
            ("rotate_secrets", rand_host(), {}, 2),         # +4.0
            ("run_forensics",  rand_host(), {}, 2),
            ("restore_backup", rand_host(), {}, 1),
        ]

    if instr_pending:
        # weight=1 (was 2) -- execute_instruction was over-represented and caused
        # the model to memorize it as the "safe default" action.
        cands += [(
            "execute_instruction", "",
            {"required_tool": random.choice(INSTRUCTION_TOOLS)},
            1,                                              # +1.2 if right, -1.0 if wrong
        )]

    if t_step > 0 and t_step % 10 == 0:
        cands += [("checkpoint_plan", rand_host(), {}, 4)]  # +2.0 on multiples of 10

    # Weighted random sample
    pool = [(tool, tgt, params) for tool, tgt, params, w in cands for _ in range(w)]
    tool, target, params = random.choice(pool)
    return {"actor": "blue", "tool_name": tool, "target": target,
            "params": params, "rationale": RATIONALE.get(tool, "respond")}

# ---------- 11) Collect SFT dataset from real env rollouts ----------
# Uses TRL "messages" format -> chat template applied automatically AND
# prompt tokens are masked from the loss (only JSON tokens contribute).
print("\n===== Phase 1: collecting SFT data from heuristic policy =====")
N_SFT_EPISODES = 50      # ~50 episodes x ~20 steps = ~1000 (obs, action) pairs
RED_TOOLS = ["recon_network", "attempt_exploit", "lateral_move", "exfiltrate_data"]
random.seed(42)

sft_pairs = []
for ep in range(N_SFT_EPISODES):
    env = CyberSelfPlayEnvironment()
    obs = env.reset()
    for t in range(40):
        if obs.done: break
        red_act = CyberAction(actor="red",
                              tool_name=RED_TOOLS[t % len(RED_TOOLS)],
                              target=f"host-{t % 6:02d}", params={})
        red_obs = env.step(red_act)
        if red_obs.done: break
        blue_action_dict = heuristic_blue_action(
            red_obs.public_state, red_obs.telemetry, t,
        )
        obs_payload = {
            "public_state":     red_obs.public_state,
            "telemetry":        red_obs.telemetry,
            "incident_summary": red_obs.incident_summary,
        }
        sft_pairs.append({
            "messages": [
                {"role": "system",    "content": SYSTEM_MSG},
                {"role": "user",      "content": _user_msg(obs_payload)},
                {"role": "assistant", "content": json.dumps(blue_action_dict, ensure_ascii=True)},
            ]
        })
        obs = env.step(CyberAction(**blue_action_dict))
print(f"Collected {len(sft_pairs)} SFT examples in messages format.")

# Print the action distribution -- if any single tool > 50%, SFT will collapse.
from collections import Counter
_dist = Counter(json.loads(p["messages"][-1]["content"])["tool_name"] for p in sft_pairs)
print("\n[SFT] Blue tool distribution in training data:")
for tool, n in _dist.most_common():
    pct = 100 * n / len(sft_pairs)
    bar = "#" * int(pct / 2)
    print(f"  {tool:<22s} {n:>4d}  {pct:5.1f}%  {bar}")
top_pct = max(_dist.values()) / len(sft_pairs)
if top_pct > 0.5:
    print(f"\nWARNING: top tool is {top_pct:.0%} of data -- expect mode collapse.")
else:
    print(f"\n[SFT] Diversity OK -- top tool is only {top_pct:.0%} of corpus.\n")

sft_dataset = Dataset.from_list(sft_pairs)

# Pre-apply the chat template -> Unsloth's SFTTrainer wants plain text input.
def _msgs_to_text(example):
    return {"text": tokenizer.apply_chat_template(
        example["messages"],
        tokenize=False,
        add_generation_prompt=False,
    )}

sft_dataset = sft_dataset.map(_msgs_to_text, remove_columns=["messages"])
print("Sample SFT text:\n", sft_dataset[0]["text"][:400], "...\n")

# ---------- 12) SFT phase ----------
print("\n===== Phase 1: SFT (imitation learning, BFD-packed) =====")
sft_args = SFTConfig(
    output_dir                  = "/content/outputs_cyber/sft",
    learning_rate               = 2e-4,
    per_device_train_batch_size = 4,
    gradient_accumulation_steps = 4,
    num_train_epochs            = 1,
    logging_steps               = 1,
    warmup_steps                = 5,
    optim                       = "adamw_8bit",
    bf16                        = use_bf16,
    fp16                        = use_fp16,
    save_strategy               = "no",
    report_to                   = "none",
    max_length                  = MAX_SEQ_LEN,
    dataset_text_field          = "text",
    packing                     = True,
    packing_strategy            = "bfd",
)
sft_trainer = SFTTrainer(
    model         = model,
    tokenizer     = tokenizer,
    args          = sft_args,
    train_dataset = sft_dataset,
)
sft_trainer.train()
print("SFT done.")

# ---------- 13) Sanity check after SFT (parses should be ~100%) ----------
# Use GREEDY decoding -- this is the truest signal of what SFT actually learned.
# Vary the env trajectory length per sample so you see different observations
# (and therefore different outputs), not 8 copies of the same one.
print("\n===== Post-SFT sanity check (greedy decoding, varied env states) =====")
FastLanguageModel.for_inference(model)
ok_count, n_check = 0, 8
example_prompt, example_gen = None, None
RED_T = ["recon_network", "attempt_exploit", "lateral_move", "exfiltrate_data"]
for i in range(n_check):
    env_t = CyberSelfPlayEnvironment(); env_t.reset()
    for t in range(random.randint(1, 6)):
        env_t.step(CyberAction(actor="red",
                               tool_name=RED_T[t % len(RED_T)],
                               target=f"host-{random.randint(0,5):02d}"))
    o = env_t.step(CyberAction(actor="red", tool_name="recon_network",
                               target=f"host-{random.randint(0,5):02d}"))
    p = obs_to_prompt({"public_state": o.public_state, "telemetry": o.telemetry,
                       "incident_summary": o.incident_summary})
    inp = tokenizer(p, return_tensors="pt").to(model.device)
    out = model.generate(
        **inp,
        max_new_tokens=128,
        do_sample=False,
        pad_token_id=tokenizer.pad_token_id,
        eos_token_id=tokenizer.eos_token_id,
    )
    gen = tokenizer.decode(out[0][inp.input_ids.shape[1]:], skip_special_tokens=True)
    _, ok = parse_action(gen)
    ok_count += int(ok)
    print(f"sample {i+1} (parses={ok}): {gen.strip()[:200]}")
    if example_prompt is None:
        example_prompt, example_gen = p, gen

parse_rate = ok_count / n_check
print(f"\nSFT parse rate: {ok_count}/{n_check} = {parse_rate:.0%}")

if parse_rate < 0.5:
    # Print one full prompt + generation so the user can SEE what the model is doing.
    print("\n--- DEBUG: full inference prompt the model is being given ---")
    print(example_prompt)
    print("--- DEBUG: full model output ---")
    print(example_gen)
    print("--- DEBUG: example SFT training text ---")
    print(sft_dataset[0]["text"][:1500])
    print("--- end debug ---\n")
    raise RuntimeError(
        f"SFT parse rate too low ({parse_rate:.0%}). "
        "GRPO will not learn -- aborting.\n"
        "Fixes: (a) increase N_SFT_EPISODES (50 -> 100), "
        "(b) increase num_train_epochs (4 -> 6), "
        "(c) try a stronger BASE_MODEL (Qwen2.5-Coder-1.5B-Instruct-bnb-4bit)."
    )
FastLanguageModel.for_training(model)

# =============================================================================
# PHASE 2 -- League (PFSP + PSRO) + GRPO  (per-round)
# =============================================================================
from collections import Counter
from statistics import mean
from transformers import TrainerCallback
from IPython.display import clear_output
import matplotlib.pyplot as plt

# --- Tunables (Kaggle T4) ---
LEAGUE_ROUNDS         = 1       # one PFSP/PSRO + mini-GRPO per round (must be >= 1)
GRPO_STEPS_PER_ROUND  = 50
N_GRPO_PROMPTS        = 64
PSRO_EVAL_EPISODES    = 4       # heuristic episodes per Red profile for PSRO replicator
PSRO_ETA              = 0.2
# How to pick the Red for each round: "pfsp" (f(w)=w(1-w)), "psro" (META_PROBS), "mix" (0.5/0.5)
OPP_SAMPLE_MODE = "psro"
assert LEAGUE_ROUNDS >= 1, "LEAGUE_ROUNDS must be >= 1 for the league+GRPO script."

# Red archetypes: (min, max) exploit pre-steps before final recon
RED_PROFILES = {
    "R-easy":  (0, 1),   # light red pressure
    "R-mid":   (0, 4),   # default spread
    "R-hard":  (3, 8),   # heavy exploit preamble
}

def env_after_red_preamble(red_name: str):
    """New env, random preamble following RED_PROFILES[red_name], then recon. Returns (env, obs before Blue)."""
    e = CyberSelfPlayEnvironment()
    e.reset()
    lo, hi = RED_PROFILES[red_name]
    n = random.randint(lo, hi)
    for _ in range(n):
        e.step(CyberAction(
            actor="red", tool_name="attempt_exploit",
            target=f"host-{random.randint(0, 5):02d}", params={},
        ))
    o = e.step(CyberAction(
        actor="red", tool_name="recon_network",
        target=f"host-{random.randint(0, 5):02d}", params={},
    ))
    return e, o

# PFSP pool (same as train_blue_vs_pool _seed_pool idea)
LEAGUE_POOL: list = [
    OpponentStats("R-easy", 0.20, 10),
    OpponentStats("R-mid", 0.50, 10),
    OpponentStats("R-hard", 0.80, 10),
]
META_PROBS = [1.0 / 3, 1.0 / 3, 1.0 / 3]  # PSRO: replicator on heuristic-eval payoffs

# Set each league round; compute_rewards reads it for aligned Red preamble
LEAGUE_CURRENT_RED = "R-mid"

def _heuristic_payoff_vector() -> list[float]:
    """Mean Blue return (heuristic policy) vs each red profile — for PSRO replicator."""
    out = []
    for name in ("R-easy", "R-mid", "R-hard"):
        s = 0.0
        for _ in range(PSRO_EVAL_EPISODES):
            e, o = env_after_red_preamble(name)
            a = heuristic_blue_action(o.public_state, o.telemetry, 0)
            o2 = e.step(CyberAction(**a))
            s += float(o2.reward or 0.0)
        out.append(s / max(1, PSRO_EVAL_EPISODES))
    return out

def _update_winrate(opp: OpponentStats, mean_r: float, n_g: int) -> None:
    blue_won = 1.0 if mean_r > 0.0 else 0.0
    new_g = opp.games + n_g
    blended = (opp.win_rate_vs_learner * opp.games + (1.0 - blue_won) * n_g) / max(1, new_g)
    opp.win_rate_vs_learner = float(min(1.0, max(0.0, blended)))
    opp.games = new_g

INVALID_PENALTY      = -1.0
DUP_TOOL_PENALTY     = -0.5
INSTR_TOOL_PENALTY   = -0.2
_REWARD_CALLS  = {"n": 0}
_PER_STEP: list  = []       # per compute_rewards call; reset at each sub-trainer
_PER_ROUND_STEP_BASE = 0   # for logging steps across mini-GRPOs

def compute_rewards(prompts, completions, **kwargs):
    n          = len(completions)
    base       = [0.0] * n
    tools      = [None] * n
    parsed_ok  = [False] * n
    debug_text = None

    for i, comp in enumerate(completions):
        text = comp if isinstance(comp, str) else comp.get("content", "")
        if debug_text is None:
            debug_text = text
        action, ok = parse_action(text)
        if not ok:
            base[i] = INVALID_PENALTY
            continue
        e, _o = env_after_red_preamble(LEAGUE_CURRENT_RED)
        try:
            obs = e.step(CyberAction(**action))
            base[i] = float(obs.reward or 0.0)
            tools[i] = action.get("tool_name")
            parsed_ok[i] = True
        except Exception:
            base[i] = INVALID_PENALTY

    counts  = Counter(t for t in tools if t)
    n_valid = sum(1 for t in tools if t)
    rewards = []
    for i in range(n):
        r = base[i]
        if parsed_ok[i] and tools[i]:
            share = counts[tools[i]] / max(1, n_valid)
            if share > 0.5:
                r += DUP_TOOL_PENALTY * (share - 0.5) * 2
            if tools[i] == "execute_instruction":
                r += INSTR_TOOL_PENALTY
        rewards.append(r)

    _REWARD_CALLS["n"] += 1
    _PER_STEP.append({
        "call": _REWARD_CALLS["n"],
        "rewards": rewards, "tools": tools, "parsed": sum(parsed_ok), "n": n,
        "tool_dist": dict(counts),
    })
    if _REWARD_CALLS["n"] % 5 == 1 and debug_text:
        top = ", ".join(f"{k}={v}" for k, v in counts.most_common(3))
        print(f"[rewards] red={LEAGUE_CURRENT_RED} call={_REWARD_CALLS['n']:3d} "
              f"parsed={sum(parsed_ok)}/{n} r_mean={sum(rewards)/n:+.2f} top={{{top}}}", flush=True)
    return rewards

def build_grpo_prompts(n: int) -> list:
    p = []
    for _ in range(n):
        _e, o = env_after_red_preamble(LEAGUE_CURRENT_RED)
        p.append({"prompt": obs_to_prompt({
            "public_state": o.public_state, "telemetry": o.telemetry,
            "incident_summary": o.incident_summary,
        })})
    return p

# Logging dirs (per-round subfolders; CURVES_DIR used by Hub upload)
OUT_DIR    = Path("/content/outputs_cyber")
CURVES_DIR = OUT_DIR / "curves"
(OUT_DIR / "league").mkdir(parents=True, exist_ok=True)
CURVES_DIR.mkdir(parents=True, exist_ok=True)
MAIN_LOG   = OUT_DIR / "train_metrics.log"
LEAGUE_JSONL = OUT_DIR / "league_state.jsonl"
JSONL_FILE  = OUT_DIR / "per_step_rewards.jsonl"


def pick_red_opponent():
    """Pick one of R-easy / R-mid / R-hard: PFSP, PSRO (meta-probs), or 50-50 mix."""
    pool = LEAGUE_POOL
    if OPP_SAMPLE_MODE == "psro":
        j = random.choices(range(3), weights=META_PROBS, k=1)[0]
        return pool[j]
    if OPP_SAMPLE_MODE == "mix":
        pf = [pfsp_weight(o.win_rate_vs_learner) for o in pool]
        s0 = sum(pf)
        pf = [x / s0 for x in pf] if s0 > 0 else [1 / 3, 1 / 3, 1 / 3]
        bl = [0.5 * pf[i] + 0.5 * META_PROBS[i] for i in range(3)]
        s1 = sum(bl)
        w = [x / s1 for x in bl]
        j = random.choices(range(3), weights=w, k=1)[0]
        return pool[j]
    return sample_opponent(pool)

class SimpleLoggerCallback(TrainerCallback):
    def __init__(self, round_idx: int, red_name: str):
        self.h = []
        self.r = round_idx
        self.red_name = red_name
        self._per_step_i = 0
        self.log_file = MAIN_LOG

        if round_idx == 0:
            self.log_file.write_text("step\tloss\treward\tround\tred\n")
            JSONL_FILE.write_text("")

    def on_log(self, args, state, control, logs=None, **kw):
        if not logs or "reward" not in logs:
            return

        gstep = _PER_ROUND_STEP_BASE + state.global_step
        recent = _PER_STEP[self._per_step_i:]
        if not recent:
            return

        self._per_step_i = len(_PER_STEP)

        flat_rewards = [r for c in recent for r in c["rewards"]]
        flat_tools = [t for c in recent for t in c["tools"] if t]

        row = {
            **logs,
            "step": gstep,
            "round": self.r,
            "red": self.red_name,
            "rewards": flat_rewards,
            "tools": flat_tools,
        }

        self.h.append(row)

        print(
            f"[R{self.r} {self.red_name}] step {gstep:4d} "
            f"loss={logs.get('loss',0):+.4f} "
            f"reward={logs.get('reward',0):+.2f}",
            flush=True,
        )

        with self.log_file.open("a") as f:
            f.write(
                f"{gstep}\t{logs.get('loss',0):.6f}\t{logs.get('reward',0):.6f}\t{self.r}\t{self.red_name}\n"
            )

        with JSONL_FILE.open("a") as f:
            f.write(json.dumps(row) + "\n")

# ---------- 18) League + GRPO loop ----------
all_hist: list = []
print("\n===== Phase 2: League (PFSP) + mini-GRPO + PSRO replicator =====")
for r in range(LEAGUE_ROUNDS):
    opp = sample_opponent(LEAGUE_POOL)
    LEAGUE_CURRENT_RED = opp.name
    print(f"\n--- League round {r+1}/{LEAGUE_ROUNDS}: [{OPP_SAMPLE_MODE}] Red = {LEAGUE_CURRENT_RED} "
          f"(pool w~={opp.win_rate_vs_learner:.2f}) ---")

    _REWARD_CALLS["n"] = 0
    _PER_STEP.clear()
    train_dataset = Dataset.from_list(build_grpo_prompts(N_GRPO_PROMPTS))
    print(f"  Built {len(train_dataset)} GRPO prompts for {LEAGUE_CURRENT_RED}.")

    training_args = GRPOConfig(
        output_dir                 = f"/content/outputs_cyber/grpo_r{r}_{opp.name}",
        learning_rate              = 5e-6,
        per_device_train_batch_size= 2,
        gradient_accumulation_steps= 4,
        num_generations            = 8,
        max_completion_length      = 128,
        max_steps                  = GRPO_STEPS_PER_ROUND,
        logging_steps              = 2,
        warmup_steps               = 6,
        optim                      = "adamw_8bit",
        bf16                       = use_bf16,
        fp16                       = use_fp16,
        use_cpu                    = not has_cuda,
        report_to                  = "none",
        temperature                = 1.0,
        top_p                      = 0.95,
        beta                       = 0.02,
        max_grad_norm              = 1.0,
    )

    trainer = GRPOTrainer(
    model          = model,
    reward_funcs   = [compute_rewards],
    args           = training_args,
    train_dataset  = train_dataset,
    callbacks      = [SimpleLoggerCallback(r, opp.name)],  # changed
  )
    trainer.train()
    all_hist.append({"round": r, "red": opp.name, "log_history": list(trainer.state.log_history or [])})
    if trainer.state.log_history:
        last_r = [x.get("reward", 0) for x in trainer.state.log_history if "reward" in x]
        round_mean = mean(last_r) if last_r else 0.0
    else:
        round_mean = 0.0
    _update_winrate(opp, round_mean, max(1, GRPO_STEPS_PER_ROUND // 2))

    payoff = _heuristic_payoff_vector()
    META_PROBS = replicator_update(payoff, META_PROBS, PSRO_ETA)  # type: ignore[assignment]
    print(f"  Heuristic payoffs (easy/mid/hard) = {[round(x,3) for x in payoff]}")
    print(f"  PSRO meta-probs  = {[round(p,3) for p in META_PROBS]}")
    print(f"  Pool win-rates: {[(o.name, round(o.win_rate_vs_learner,2)) for o in LEAGUE_POOL]}")

    _PER_ROUND_STEP_BASE += GRPO_STEPS_PER_ROUND
    (OUT_DIR / f"log_history_r{r}_{opp.name}.json").write_text(
        json.dumps(trainer.state.log_history, indent=2)
    )
    FastLanguageModel.for_training(model)  # Unsloth mode after for_inference if any

    # ----- Final plot for THIS round -----
    round_history = trainer.state.log_history or []

    def _series_round(key):
        xs, ys = [], []
        for row in round_history:
            if key in row and "step" in row:
                xs.append(row["step"])
                ys.append(row[key])
        return xs, ys

    fig, ax = plt.subplots(1, 2, figsize=(10, 4))

    # Reward
    rx, ry = _series_round("reward")
    if rx:
        ax[0].plot(rx, ry)
    ax[0].set_title(f"Round {r} ({opp.name}) Reward")
    ax[0].grid(True)

    # Loss
    lx, ly = _series_round("loss")
    if not lx:
        lx, ly = _series_round("train_loss")
    if lx:
        ax[1].plot(lx, ly)
    ax[1].set_title("Loss")
    ax[1].grid(True)

    plt.tight_layout()

    save_path = OUT_DIR / f"round_{r}_{opp.name}_final.png"
    plt.savefig(save_path, dpi=120)
    plt.close()

    print(f"Saved round plot -> {save_path}")

(OUT_DIR / "league_log.json").write_text(json.dumps(all_hist, indent=2))
comb = []
for h in all_hist:
    for row in h.get("log_history") or []:
        comb.append({**row, "league_round": h.get("round"), "round_red": h.get("red")})
(OUT_DIR / "log_history_combined.json").write_text(json.dumps(comb, indent=2))
print(f"\nWrote {OUT_DIR / 'league_log.json'}, {OUT_DIR / 'log_history_combined.json'}, {LEAGUE_JSONL}")
# `trainer` / `training_args` refer to the last league round (used in §19 + save)

# ---------- 19) Final summary plot + raw metrics dump (last round + optional combined) ----------
OUT = Path(training_args.output_dir)
OUT.mkdir(parents=True, exist_ok=True)
history = list(trainer.state.log_history or [])
(OUT / "log_history.json").write_text(json.dumps(history, indent=2))
history_combined = comb  # all rounds, with league_round in each row

def _series(key):
    xs, ys = [], []
    for r in history:
        if key in r and "step" in r:
            xs.append(r["step"]); ys.append(r[key])
    return xs, ys

fig, axes = plt.subplots(2, 2, figsize=(13, 9))
fig.suptitle("CyberSelfPlay SFT+GRPO -- training curves", fontsize=14)

ax = axes[0, 0]
rx, ry = _series("reward"); sx, sy = _series("reward_std")
if rx: ax.plot(rx, ry, color="#2563eb", linewidth=2, label="env reward")
if sx and len(ry) == len(sy):
    ax.fill_between(sx, [m-s for m,s in zip(ry,sy)], [m+s for m,s in zip(ry,sy)],
                    color="#2563eb", alpha=0.15, label="±1 std")
ax.axhline(0, color="gray", linestyle=":", alpha=0.5)
ax.set_title("Env reward progression"); ax.set_xlabel("step")
ax.legend(fontsize=8); ax.grid(alpha=0.3)

ax = axes[0, 1]
kx, ky = _series("kl")
if kx: ax.plot(kx, ky, color="#9333ea", linewidth=2)
ax.set_title("KL divergence"); ax.set_xlabel("step"); ax.grid(alpha=0.3)

ax = axes[1, 0]
lx, ly = _series("loss")
if not lx: lx, ly = _series("train_loss")
if lx: ax.plot(lx, ly, color="#be123c", linewidth=2)
ax.set_title("Training loss"); ax.set_xlabel("step"); ax.grid(alpha=0.3)

ax = axes[1, 1]
for k, color, ls in [("completions/mean_length", "#0891b2", "-"),
                     ("completions/min_length",  "#64748b", "--"),
                     ("completions/max_length",  "#64748b", ":")]:
    xs, ys = _series(k)
    if xs: ax.plot(xs, ys, color=color, linestyle=ls, label=k.split("/")[-1])
ax.set_title("Completion length"); ax.set_xlabel("step")
ax.legend(fontsize=8); ax.grid(alpha=0.3)

fig.tight_layout(rect=[0, 0, 1, 0.96])
fig.savefig(OUT / "training_curves.png", dpi=120, bbox_inches="tight")
plt.show()
print(f"Saved -> {OUT/'training_curves.png'} and {OUT/'log_history.json'}")

# Combined plot over all league rounds
def _series_c(rows, key):
    xs, ys = [], []
    for row in rows:
        if key in row and "step" in row:
            xs.append(row["step"])
            ys.append(row[key])
    return xs, ys

if history_combined:
    fig2, ax2 = plt.subplots(1, 1, figsize=(10, 4))
    cx, cy = _series_c(history_combined, "reward")
    if cx:
        ax2.plot(cx, cy, color="#1d4ed8", linewidth=1.5)
    ax2.axhline(0, color="gray", ls=":", alpha=0.5)
    ax2.set_title("Mean reward (all league rounds, TRL log steps, combined export)")
    ax2.set_xlabel("step"); ax2.grid(alpha=0.3)
    fig2.tight_layout()
    fig2.savefig(OUT_DIR / "training_curves_all_rounds.png", dpi=120, bbox_inches="tight")
    plt.show()
    print(f"Saved -> {OUT_DIR / 'training_curves_all_rounds.png'}")

# ---------- 20) Save adapter ----------
SAVE_DIR = "/content/outputs_cyber/cyber-blue-grpo-lora"
trainer.save_model(SAVE_DIR)
tokenizer.save_pretrained(SAVE_DIR)
print(f"\nSaved LoRA adapter to {SAVE_DIR}")

# ---------- 21) (Optional) Push to HF Hub ----------
PUSH_TO_HUB    = True
HF_TARGET_REPO = "HarshitShri026/cyber-blue-grpo"

try:
    from kaggle_secrets import UserSecretsClient
    HF_TOKEN = UserSecretsClient().get_secret("HF_TOKEN")
except Exception:
    HF_TOKEN = ""

if PUSH_TO_HUB and HF_TOKEN:
    from huggingface_hub import HfApi, login
    login(token=HF_TOKEN)
    api = HfApi()
    api.create_repo(repo_id=HF_TARGET_REPO, repo_type="model", exist_ok=True)
    api.upload_folder(repo_id=HF_TARGET_REPO, folder_path=SAVE_DIR, repo_type="model")
    # Top-level training artifacts.
    for fname in (
        "training_curves.png",
        "training_curves_all_rounds.png",
        "log_history.json",
        "log_history_combined.json",
        "league_log.json",
        "train_metrics.log",
        "per_step_rewards.jsonl",
    ):
        fpath = OUT_DIR / fname if fname in (
            "training_curves_all_rounds.png",
            "log_history_combined.json",
            "league_log.json",
            "train_metrics.log",
            "per_step_rewards.jsonl",
        ) else OUT / fname
        if fpath.exists():
            api.upload_file(path_or_fileobj=str(fpath), path_in_repo=fname,
                            repo_id=HF_TARGET_REPO, repo_type="model")
    # Per-step PNGs (one image per logging step) -> uploaded under curves/.
    if CURVES_DIR.exists():
        api.upload_folder(repo_id=HF_TARGET_REPO, folder_path=str(CURVES_DIR),
                          path_in_repo="curves", repo_type="model")
    print(f"Uploaded -> https://huggingface.co/{HF_TARGET_REPO}")
    print(f"  per-step curves -> https://huggingface.co/{HF_TARGET_REPO}/tree/main/curves")
else:
    print("[push] skipped -- set HF_TOKEN as a Kaggle Secret to enable.")

# ---------- 22) Final sanity check (varied env states) ----------
print("\n===== Post-GRPO sanity check =====")
FastLanguageModel.for_inference(model)
for i in range(3):
    env_t = CyberSelfPlayEnvironment(); env_t.reset()
    for t in range(random.randint(1, 6)):
        env_t.step(CyberAction(actor="red",
                               tool_name=RED_T[t % len(RED_T)],
                               target=f"host-{random.randint(0,5):02d}"))
    o = env_t.step(CyberAction(actor="red", tool_name="recon_network",
                               target=f"host-{random.randint(0,5):02d}"))
    p = obs_to_prompt({"public_state": o.public_state, "telemetry": o.telemetry,
                       "incident_summary": o.incident_summary})
    inp = tokenizer(p, return_tensors="pt").to(model.device)
    out = model.generate(
        **inp,
        max_new_tokens=128,
        do_sample=False,
        pad_token_id=tokenizer.pad_token_id,
        eos_token_id=tokenizer.eos_token_id,
    )
    gen = tokenizer.decode(out[0][inp.input_ids.shape[1]:], skip_special_tokens=True)
    action, ok = parse_action(gen)
    print(f"\n--- sample {i+1} (parse_ok={ok}) ---")
    print(gen.strip()); print("Parsed:", action)
print("\nDone.")
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Building wheel for trl (pyproject.toml) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# unsloth-zoo 2026.4.9 requires datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1, but you have datasets 4.8.4 which is incompatible.
# unsloth-zoo 2026.4.9 requires trl!=0.19.0,<=0.24.0,>=0.18.2, but you have trl 1.3.0.dev0 which is incompatible.
# Cloning into 'cyberselfplay-env'...
# remote: Enumerating objects: 237, done.
# remote: Counting objects: 100% (237/237), done.
# remote: Compressing objects: 100% (234/234), done.
# remote: Total 237 (delta 116), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (237/237), 248.68 KiB | 1.76 MiB/s, done.
# Resolving deltas: 100% (116/116), done.
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
#   Building editable for openenv-cyber-selfplay (pyproject.toml) ... done
# CUDA: True | bf16: False | fp16: True
# GPU: Tesla T4
# ==((====))==  Unsloth 2026.4.8: Fast Qwen2 patching. Transformers: 5.5.0.
#    \\   /|    Tesla T4. Num GPUs = 1. Max memory: 14.563 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.10.0+cu128. CUDA: 7.5. CUDA Toolkit: 12.8. Triton: 3.6.0
# \        /    Bfloat16 = FALSE. FA [Xformers = None. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# Loading weights:   0%|          | 0/338 [00:00<?, ?it/s]
# config.json: 0.00B [00:00, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# added_tokens.json:   0%|          | 0.00/632 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/613 [00:00<?, ?B/s]
# ===== Phase 1: collecting SFT data from heuristic policy =====
# Collected 2000 SFT examples in messages format.
#
# [SFT] Blue tool distribution in training data:
#   triage_alerts           234   11.7%  #####
#   checkpoint_plan         208   10.4%  #####
#   harden_policy           200   10.0%  #####
#   execute_instruction     197    9.8%  ####
#   query_siem              192    9.6%  ####
#   disable_account         189    9.4%  ####
#   deploy_patch            187    9.3%  ####
#   publish_ioc_blocklist   187    9.3%  ####
#   reconcile_state         168    8.4%  ####
#   restore_backup           62    3.1%  #
#   rotate_secrets           59    3.0%  #
#   run_forensics            59    3.0%  #
#   isolate_host             58    2.9%  #
#
# [SFT] Diversity OK -- top tool is only 12% of corpus.
# Map:   0%|          | 0/2000 [00:00<?, ? examples/s]
# Sample SFT text:
#  <|im_start|>system
# You are the Blue defender in a cyber self-play game.
# You MUST output ONLY a valid JSON object.
# No explanation. No extra text. No prefixes/suffixes.
# Output exactly ONE JSON object and stop.
#
# Schema: {"actor":"blue","tool_name":<one of ['checkpoint_plan', 'deploy_patch', 'disable_account', 'execute_instruction', 'harden_policy', 'isolate_host', 'publish_ioc_blocklist', 'query_siem ...
#
#
# ===== Phase 1: SFT (imitation learning, BFD-packed) =====
# Unsloth: Sample packing skipped (custom data collator detected).
# Unsloth: Tokenizing ["text"] (num_proc=6):   0%|          | 0/2000 [00:00<?, ? examples/s]
# Unsloth: Will smartly offload gradients to save VRAM!
# {'loss': '3.282', 'grad_norm': '0.9929', 'learning_rate': '0', 'epoch': '0.008'}
# {'loss': '3.265', 'grad_norm': '0.9938', 'learning_rate': '4e-05', 'epoch': '0.016'}
# {'loss': '3.222', 'grad_norm': '0.9298', 'learning_rate': '8e-05', 'epoch': '0.024'}
# {'loss': '3.138', 'grad_norm': '0.8297', 'learning_rate': '0.00012', 'epoch': '0.032'}
# {'loss': '2.904', 'grad_norm': '0.7425', 'learning_rate': '0.00016', 'epoch': '0.04'}
# {'loss': '2.711', 'grad_norm': '0.741', 'learning_rate': '0.0002', 'epoch': '0.048'}
# {'loss': '2.567', 'grad_norm': '0.8607', 'learning_rate': '0.0001983', 'epoch': '0.056'}
# {'loss': '2.341', 'grad_norm': '0.8737', 'learning_rate': '0.0001967', 'epoch': '0.064'}
# {'loss': '2.107', 'grad_norm': '0.8527', 'learning_rate': '0.000195', 'epoch': '0.072'}
# {'loss': '1.927', 'grad_norm': '0.9165', 'learning_rate': '0.0001933', 'epoch': '0.08'}
# {'loss': '1.715', 'grad_norm': '0.9701', 'learning_rate': '0.0001917', 'epoch': '0.088'}
# {'loss': '1.517', 'grad_norm': '1.094', 'learning_rate': '0.00019', 'epoch': '0.096'}
# {'loss': '1.321', 'grad_norm': '1.242', 'learning_rate': '0.0001883', 'epoch': '0.104'}
# {'loss': '1.108', 'grad_norm': '1.424', 'learning_rate': '0.0001867', 'epoch': '0.112'}
# {'loss': '0.8732', 'grad_norm': '1.742', 'learning_rate': '0.000185', 'epoch': '0.12'}
# {'loss': '0.6998', 'grad_norm': '1.507', 'learning_rate': '0.0001833', 'epoch': '0.128'}
# {'loss': '0.5852', 'grad_norm': '1.29', 'learning_rate': '0.0001817', 'epoch': '0.136'}
# {'loss': '0.4257', 'grad_norm': '1.142', 'learning_rate': '0.00018', 'epoch': '0.144'}
# {'loss': '0.3605', 'grad_norm': '0.9208', 'learning_rate': '0.0001783', 'epoch': '0.152'}
# {'loss': '0.258', 'grad_norm': '0.7561', 'learning_rate': '0.0001767', 'epoch': '0.16'}
# {'loss': '0.2398', 'grad_norm': '0.6479', 'learning_rate': '0.000175', 'epoch': '0.168'}
# {'loss': '0.1886', 'grad_norm': '0.5788', 'learning_rate': '0.0001733', 'epoch': '0.176'}
# {'loss': '0.154', 'grad_norm': '0.4831', 'learning_rate': '0.0001717', 'epoch': '0.184'}
# {'loss': '0.1275', 'grad_norm': '0.4015', 'learning_rate': '0.00017', 'epoch': '0.192'}
# {'loss': '0.1155', 'grad_norm': '0.3062', 'learning_rate': '0.0001683', 'epoch': '0.2'}
# {'loss': '0.1033', 'grad_norm': '0.4277', 'learning_rate': '0.0001667', 'epoch': '0.208'}
# {'loss': '0.08777', 'grad_norm': '0.3492', 'learning_rate': '0.000165', 'epoch': '0.216'}
# {'loss': '0.09482', 'grad_norm': '0.4031', 'learning_rate': '0.0001633', 'epoch': '0.224'}
# {'loss': '0.08253', 'grad_norm': '0.3287', 'learning_rate': '0.0001617', 'epoch': '0.232'}
# {'loss': '0.08133', 'grad_norm': '0.3709', 'learning_rate': '0.00016', 'epoch': '0.24'}
# {'loss': '0.07919', 'grad_norm': '0.2698', 'learning_rate': '0.0001583', 'epoch': '0.248'}
# {'loss': '0.06134', 'grad_norm': '0.2098', 'learning_rate': '0.0001567', 'epoch': '0.256'}
# {'loss': '0.06234', 'grad_norm': '0.2296', 'learning_rate': '0.000155', 'epoch': '0.264'}
# {'loss': '0.07793', 'grad_norm': '0.2307', 'learning_rate': '0.0001533', 'epoch': '0.272'}
# {'loss': '0.05148', 'grad_norm': '0.173', 'learning_rate': '0.0001517', 'epoch': '0.28'}
# {'loss': '0.06311', 'grad_norm': '0.1755', 'learning_rate': '0.00015', 'epoch': '0.288'}
# {'loss': '0.05154', 'grad_norm': '0.1424', 'learning_rate': '0.0001483', 'epoch': '0.296'}
# {'loss': '0.05334', 'grad_norm': '0.1764', 'learning_rate': '0.0001467', 'epoch': '0.304'}
# {'loss': '0.04573', 'grad_norm': '0.134', 'learning_rate': '0.000145', 'epoch': '0.312'}
# {'loss': '0.03952', 'grad_norm': '0.1472', 'learning_rate': '0.0001433', 'epoch': '0.32'}
# {'loss': '0.04482', 'grad_norm': '0.1329', 'learning_rate': '0.0001417', 'epoch': '0.328'}
# {'loss': '0.03572', 'grad_norm': '0.1296', 'learning_rate': '0.00014', 'epoch': '0.336'}
# {'loss': '0.04235', 'grad_norm': '0.1943', 'learning_rate': '0.0001383', 'epoch': '0.344'}
# {'loss': '0.04115', 'grad_norm': '0.1445', 'learning_rate': '0.0001367', 'epoch': '0.352'}
# {'loss': '0.03658', 'grad_norm': '0.1104', 'learning_rate': '0.000135', 'epoch': '0.36'}
# {'loss': '0.03723', 'grad_norm': '0.1645', 'learning_rate': '0.0001333', 'epoch': '0.368'}
# {'loss': '0.03626', 'grad_norm': '0.09233', 'learning_rate': '0.0001317', 'epoch': '0.376'}
# {'loss': '0.03878', 'grad_norm': '0.1127', 'learning_rate': '0.00013', 'epoch': '0.384'}
# {'loss': '0.03008', 'grad_norm': '0.08121', 'learning_rate': '0.0001283', 'epoch': '0.392'}
# {'loss': '0.03602', 'grad_norm': '0.1382', 'learning_rate': '0.0001267', 'epoch': '0.4'}
# {'loss': '0.03251', 'grad_norm': '0.08849', 'learning_rate': '0.000125', 'epoch': '0.408'}
# {'loss': '0.03622', 'grad_norm': '0.1038', 'learning_rate': '0.0001233', 'epoch': '0.416'}
# {'loss': '0.02996', 'grad_norm': '0.06641', 'learning_rate': '0.0001217', 'epoch': '0.424'}
# {'loss': '0.03268', 'grad_norm': '0.08004', 'learning_rate': '0.00012', 'epoch': '0.432'}
# {'loss': '0.03317', 'grad_norm': '0.1359', 'learning_rate': '0.0001183', 'epoch': '0.44'}
# {'loss': '0.03279', 'grad_norm': '0.0929', 'learning_rate': '0.0001167', 'epoch': '0.448'}
# {'loss': '0.03452', 'grad_norm': '0.0929', 'learning_rate': '0.000115', 'epoch': '0.456'}
# {'loss': '0.03141', 'grad_norm': '0.09167', 'learning_rate': '0.0001133', 'epoch': '0.464'}
# {'loss': '0.0308', 'grad_norm': '0.09125', 'learning_rate': '0.0001117', 'epoch': '0.472'}
# {'loss': '0.03053', 'grad_norm': '0.08447', 'learning_rate': '0.00011', 'epoch': '0.48'}
# {'loss': '0.03142', 'grad_norm': '0.09485', 'learning_rate': '0.0001083', 'epoch': '0.488'}
# {'loss': '0.03301', 'grad_norm': '0.07275', 'learning_rate': '0.0001067', 'epoch': '0.496'}
# {'loss': '0.032', 'grad_norm': '0.1167', 'learning_rate': '0.000105', 'epoch': '0.504'}
# {'loss': '0.03153', 'grad_norm': '0.08346', 'learning_rate': '0.0001033', 'epoch': '0.512'}
# {'loss': '0.0298', 'grad_norm': '0.1892', 'learning_rate': '0.0001017', 'epoch': '0.52'}
# {'loss': '0.03199', 'grad_norm': '0.09297', 'learning_rate': '0.0001', 'epoch': '0.528'}
# {'loss': '0.02914', 'grad_norm': '0.08028', 'learning_rate': '9.833e-05', 'epoch': '0.536'}
# {'loss': '0.02685', 'grad_norm': '0.06364', 'learning_rate': '9.667e-05', 'epoch': '0.544'}
# {'loss': '0.03299', 'grad_norm': '0.1223', 'learning_rate': '9.5e-05', 'epoch': '0.552'}
# {'loss': '0.02959', 'grad_norm': '0.08719', 'learning_rate': '9.333e-05', 'epoch': '0.56'}
# {'loss': '0.03048', 'grad_norm': '0.1187', 'learning_rate': '9.167e-05', 'epoch': '0.568'}
# {'loss': '0.02966', 'grad_norm': '0.07952', 'learning_rate': '9e-05', 'epoch': '0.576'}
# {'loss': '0.02877', 'grad_norm': '0.06257', 'learning_rate': '8.833e-05', 'epoch': '0.584'}
# {'loss': '0.02799', 'grad_norm': '0.1282', 'learning_rate': '8.667e-05', 'epoch': '0.592'}
# {'loss': '0.03063', 'grad_norm': '0.09305', 'learning_rate': '8.5e-05', 'epoch': '0.6'}
# {'loss': '0.03011', 'grad_norm': '0.08728', 'learning_rate': '8.333e-05', 'epoch': '0.608'}
# {'loss': '0.02709', 'grad_norm': '0.08084', 'learning_rate': '8.167e-05', 'epoch': '0.616'}
# {'loss': '0.03143', 'grad_norm': '0.1212', 'learning_rate': '8e-05', 'epoch': '0.624'}
# {'loss': '0.02862', 'grad_norm': '0.08064', 'learning_rate': '7.833e-05', 'epoch': '0.632'}
# {'loss': '0.0303', 'grad_norm': '0.06867', 'learning_rate': '7.667e-05', 'epoch': '0.64'}
# {'loss': '0.02932', 'grad_norm': '0.1015', 'learning_rate': '7.5e-05', 'epoch': '0.648'}
# {'loss': '0.02965', 'grad_norm': '0.1098', 'learning_rate': '7.333e-05', 'epoch': '0.656'}
# {'loss': '0.02921', 'grad_norm': '0.05757', 'learning_rate': '7.167e-05', 'epoch': '0.664'}
# {'loss': '0.03009', 'grad_norm': '0.09172', 'learning_rate': '7e-05', 'epoch': '0.672'}
# {'loss': '0.02705', 'grad_norm': '0.06926', 'learning_rate': '6.833e-05', 'epoch': '0.68'}
# {'loss': '0.03111', 'grad_norm': '0.08825', 'learning_rate': '6.667e-05', 'epoch': '0.688'}
# {'loss': '0.02748', 'grad_norm': '0.09442', 'learning_rate': '6.5e-05', 'epoch': '0.696'}
# {'loss': '0.02804', 'grad_norm': '0.06864', 'learning_rate': '6.333e-05', 'epoch': '0.704'}
# {'loss': '0.02793', 'grad_norm': '0.09018', 'learning_rate': '6.167e-05', 'epoch': '0.712'}
# {'loss': '0.02975', 'grad_norm': '0.07552', 'learning_rate': '6e-05', 'epoch': '0.72'}
# {'loss': '0.03145', 'grad_norm': '0.09672', 'learning_rate': '5.833e-05', 'epoch': '0.728'}
# {'loss': '0.0307', 'grad_norm': '0.08089', 'learning_rate': '5.667e-05', 'epoch': '0.736'}
# {'loss': '0.03025', 'grad_norm': '0.08971', 'learning_rate': '5.5e-05', 'epoch': '0.744'}
# {'loss': '0.02769', 'grad_norm': '0.06722', 'learning_rate': '5.333e-05', 'epoch': '0.752'}
# {'loss': '0.02555', 'grad_norm': '0.09389', 'learning_rate': '5.167e-05', 'epoch': '0.76'}
# {'loss': '0.02916', 'grad_norm': '0.09225', 'learning_rate': '5e-05', 'epoch': '0.768'}
# {'loss': '0.029', 'grad_norm': '0.08047', 'learning_rate': '4.833e-05', 'epoch': '0.776'}
# {'loss': '0.02972', 'grad_norm': '0.09125', 'learning_rate': '4.667e-05', 'epoch': '0.784'}
# {'loss': '0.02829', 'grad_norm': '0.06079', 'learning_rate': '4.5e-05', 'epoch': '0.792'}
# {'loss': '0.02858', 'grad_norm': '0.05881', 'learning_rate': '4.333e-05', 'epoch': '0.8'}
# {'loss': '0.03143', 'grad_norm': '0.07553', 'learning_rate': '4.167e-05', 'epoch': '0.808'}
# {'loss': '0.02871', 'grad_norm': '0.07643', 'learning_rate': '4e-05', 'epoch': '0.816'}
# {'loss': '0.02985', 'grad_norm': '0.09343', 'learning_rate': '3.833e-05', 'epoch': '0.824'}
# {'loss': '0.02906', 'grad_norm': '0.1086', 'learning_rate': '3.667e-05', 'epoch': '0.832'}
# {'loss': '0.02751', 'grad_norm': '0.08024', 'learning_rate': '3.5e-05', 'epoch': '0.84'}
# {'loss': '0.02923', 'grad_norm': '0.07691', 'learning_rate': '3.333e-05', 'epoch': '0.848'}
# {'loss': '0.02813', 'grad_norm': '0.09278', 'learning_rate': '3.167e-05', 'epoch': '0.856'}
# {'loss': '0.02904', 'grad_norm': '0.06018', 'learning_rate': '3e-05', 'epoch': '0.864'}
# {'loss': '0.02718', 'grad_norm': '0.07135', 'learning_rate': '2.833e-05', 'epoch': '0.872'}
# {'loss': '0.02729', 'grad_norm': '0.06362', 'learning_rate': '2.667e-05', 'epoch': '0.88'}
# {'loss': '0.02911', 'grad_norm': '0.07539', 'learning_rate': '2.5e-05', 'epoch': '0.888'}
# {'loss': '0.02705', 'grad_norm': '0.05079', 'learning_rate': '2.333e-05', 'epoch': '0.896'}
# {'loss': '0.02804', 'grad_norm': '0.07779', 'learning_rate': '2.167e-05', 'epoch': '0.904'}
# {'loss': '0.02596', 'grad_norm': '0.06251', 'learning_rate': '2e-05', 'epoch': '0.912'}
# {'loss': '0.02657', 'grad_norm': '0.07065', 'learning_rate': '1.833e-05', 'epoch': '0.92'}
# {'loss': '0.03083', 'grad_norm': '0.08933', 'learning_rate': '1.667e-05', 'epoch': '0.928'}
# {'loss': '0.02898', 'grad_norm': '0.09633', 'learning_rate': '1.5e-05', 'epoch': '0.936'}
# {'loss': '0.03008', 'grad_norm': '0.1122', 'learning_rate': '1.333e-05', 'epoch': '0.944'}
# {'loss': '0.02623', 'grad_norm': '0.06532', 'learning_rate': '1.167e-05', 'epoch': '0.952'}
# {'loss': '0.02675', 'grad_norm': '0.07082', 'learning_rate': '1e-05', 'epoch': '0.96'}
# {'loss': '0.02817', 'grad_norm': '0.06401', 'learning_rate': '8.333e-06', 'epoch': '0.968'}
# {'loss': '0.02843', 'grad_norm': '0.081', 'learning_rate': '6.667e-06', 'epoch': '0.976'}
# {'loss': '0.02809', 'grad_norm': '0.09054', 'learning_rate': '5e-06', 'epoch': '0.984'}
# {'loss': '0.02818', 'grad_norm': '0.07168', 'learning_rate': '3.333e-06', 'epoch': '0.992'}
# {'loss': '0.02879', 'grad_norm': '0.07765', 'learning_rate': '1.667e-06', 'epoch': '1'}
# {'train_runtime': '516.5', 'train_samples_per_second': '3.872', 'train_steps_per_second': '0.242', 'train_loss': '0.3263', 'epoch': '1'}
# SFT done.
#
# ===== Post-SFT sanity check (greedy decoding, varied env states) =====
# sample 1 (parses=True): {"actor": "blue", "tool_name": "execute_instruction", "target": "", "params": {"required_tool": "publish_ioc_blocklist"}, "rationale": "follow playbook"}
# sample 2 (parses=True): {"actor": "blue", "tool_name": "execute_instruction", "target": "", "params": {"required_tool": "publish_ioc_blocklist"}, "rationale": "follow playbook"}
# sample 3 (parses=True): {"actor": "blue", "tool_name": "execute_instruction", "target": "", "params": {"required_tool": "publish_ioc_blocklist"}, "rationale": "follow playbook"}
# sample 4 (parses=True): {"actor": "blue", "tool_name": "execute_instruction", "target": "", "params": {"required_tool": "publish_ioc_blocklist"}, "rationale": "follow playbook"}
# sample 5 (parses=True): {"actor": "blue", "tool_name": "execute_instruction", "target": "", "params": {"required_tool": "publish_ioc_blocklist"}, "rationale": "follow playbook"}
# sample 6 (parses=True): {"actor": "blue", "tool_name": "execute_instruction", "target": "", "params": {"required_tool": "publish_ioc_blocklist"}, "rationale": "follow playbook"}
# sample 7 (parses=True): {"actor": "blue", "tool_name": "execute_instruction", "target": "", "params": {"required_tool": "publish_ioc_blocklist"}, "rationale": "follow playbook"}
# sample 8 (parses=True): {"actor": "blue", "tool_name": "execute_instruction", "target": "", "params": {"required_tool": "publish_ioc_blocklist"}, "rationale": "follow playbook"}
#
# SFT parse rate: 8/8 = 100%
#
# ===== Phase 2: League (PFSP) + mini-GRPO + PSRO replicator =====
#
# --- League round 1/1: [psro] Red = R-hard (pool w~=0.80) ---
#   Built 64 GRPO prompts for R-hard.
# Unsloth: Will smartly offload gradients to save VRAM!
# [rewards] red=R-hard call=  1 parsed=8/8 r_mean=+1.02 top={triage_alerts=2, disable_account=2, deploy_patch=2}
# [R0 R-hard] step    2 loss=+0.0052 reward=+0.65
# {'loss': '0.005151', 'grad_norm': '0.1916', 'learning_rate': '8.333e-07', 'num_tokens': '5069', 'completions/mean_length': '37.81', 'completions/min_length': '36.5', 'completions/max_length': '40.5', 'completions/clipped_ratio': '0', 'completions/mean_terminated_length': '37.81', 'completions/min_terminated_length': '36.5', 'completions/max_terminated_length': '40.5', 'rewards/compute_rewards/mean': '0.65', 'rewards/compute_rewards/std': '1.376', 'reward': '0.65', 'reward_std': '1.376', 'frac_reward_zero_std': '0', 'completion_length': '37.81', 'kl': '0.6849', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'step_time': '7.251', 'epoch': '0.03125'}
# [R0 R-hard] step    4 loss=+0.0085 reward=+0.56
# {'loss': '0.008535', 'grad_norm': '0.7222', 'learning_rate': '2.5e-06', 'num_tokens': '1.015e+04', 'completions/mean_length': '38.75', 'completions/min_length': '37', 'completions/max_length': '40.5', 'completions/clipped_ratio': '0', 'completions/mean_terminated_length': '38.75', 'completions/min_terminated_length': '37', 'completions/max_terminated_length': '40.5', 'rewards/compute_rewards/mean': '0.5625', 'rewards/compute_rewards/std': '1.327', 'reward': '0.5625', 'reward_std': '1.327', 'frac_reward_zero_std': '0', 'completion_length': '38.75', 'kl': '0.6184', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'step_time': '7.305', 'epoch': '0.0625'}
# [rewards] red=R-hard call=  6 parsed=8/8 r_mean=+1.01 top={harden_policy=4, triage_alerts=2, reconcile_state=1}
# [R0 R-hard] step    6 loss=+0.0140 reward=+0.74
# {'loss': '0.01403', 'grad_norm': '0.6067', 'learning_rate': '4.167e-06', 'num_tokens': '1.524e+04', 'completions/mean_length': '38.94', 'completions/min_length': '37.5', 'completions/max_length': '40.5', 'completions/clipped_ratio': '0', 'completions/mean_terminated_length': '38.94', 'completions/min_terminated_length': '37.5', 'completions/max_terminated_length': '40.5', 'rewards/compute_rewards/mean': '0.7438', 'rewards/compute_rewards/std': '2.262', 'reward': '0.7438', 'reward_std': '2.262', 'frac_reward_zero_std': '0', 'completion_length': '38.94', 'kl': '0.6735', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'step_time': '7.359', 'epoch': '0.09375'}
# [R0 R-hard] step    8 loss=+0.0060 reward=+0.47
# {'loss': '0.006042', 'grad_norm': '0.6465', 'learning_rate': '4.886e-06', 'num_tokens': '2.033e+04', 'completions/mean_length': '39', 'completions/min_length': '36.5', 'completions/max_length': '40.5', 'completions/clipped_ratio': '0', 'completions/mean_terminated_length': '39', 'completions/min_terminated_length': '36.5', 'completions/max_terminated_length': '40.5', 'rewards/compute_rewards/mean': '0.4734', 'rewards/compute_rewards/std': '1.15', 'reward': '0.4734', 'reward_std': '1.15', 'frac_reward_zero_std': '0', 'completion_length': '39', 'kl': '0.6435', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'step_time': '7.054', 'epoch': '0.125'}
# [R0 R-hard] step   10 loss=+0.0088 reward=+1.66
# {'loss': '0.008814', 'grad_norm': '0.3875', 'learning_rate': '4.659e-06', 'num_tokens': '2.541e+04', 'completions/mean_length': '38.44', 'completions/min_length': '37', 'completions/max_length': '40', 'completions/clipped_ratio': '0', 'completions/mean_terminated_length': '38.44', 'completions/min_terminated_length': '37', 'completions/max_terminated_length': '40', 'rewards/compute_rewards/mean': '1.656', 'rewards/compute_rewards/std': '1.56', 'reward': '1.656', 'reward_std': '1.56', 'frac_reward_zero_std': '0', 'completion_length': '38.44', 'kl': '0.5808', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'step_time': '6.997', 'epoch': '0.1562'}
# [rewards] red=R-hard call= 11 parsed=8/8 r_mean=+1.32 top={triage_alerts=7, query_siem=1}
# [R0 R-hard] step   12 loss=+0.0156 reward=+1.49
# {'loss': '0.01555', 'grad_norm': '0.2862', 'learning_rate': '4.432e-06', 'num_tokens': '3.049e+04', 'completions/mean_length': '38.88', 'completions/min_length': '37', 'completions/max_length': '40', 'completions/clipped_ratio': '0', 'completions/mean_terminated_length': '38.88', 'completions/min_terminated_length': '37', 'completions/max_terminated_length': '40', 'rewards/compute_rewards/mean': '1.486', 'rewards/compute_rewards/std': '0.9514', 'reward': '1.486', 'reward_std': '0.9514', 'frac_reward_zero_std': '0', 'completion_length': '38.88', 'kl': '0.5313', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'step_time': '7.14', 'epoch': '0.1875'}
# [R0 R-hard] step   14 loss=+0.0267 reward=+1.45
# {'loss': '0.02668', 'grad_norm': '0.7089', 'learning_rate': '4.205e-06', 'num_tokens': '3.558e+04', 'completions/mean_length': '39.19', 'completions/min_length': '37', 'completions/max_length': '40.5', 'completions/clipped_ratio': '0', 'completions/mean_terminated_length': '39.19', 'completions/min_terminated_length': '37', 'completions/max_terminated_length': '40.5', 'rewards/compute_rewards/mean': '1.453', 'rewards/compute_rewards/std': '1.435', 'reward': '1.453', 'reward_std': '1.435', 'frac_reward_zero_std': '0', 'completion_length': '39.19', 'kl': '0.6314', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'step_time': '7.283', 'epoch': '0.2188'}
# [rewards] red=R-hard call= 16 parsed=8/8 r_mean=+2.06 top={triage_alerts=5, harden_policy=1, reconcile_state=1}
# [R0 R-hard] step   16 loss=+0.0190 reward=+1.47
# {'loss': '0.01899', 'grad_norm': '0.5829', 'learning_rate': '3.977e-06', 'num_tokens': '4.068e+04', 'completions/mean_length': '39.25', 'completions/min_length': '38', 'completions/max_length': '41', 'completions/clipped_ratio': '0', 'completions/mean_terminated_length': '39.25', 'completions/min_terminated_length': '38', 'completions/max_terminated_length': '41', 'rewards/compute_rewards/mean': '1.47', 'rewards/compute_rewards/std': '1.621', 'reward': '1.47', 'reward_std': '1.621', 'frac_reward_zero_std': '0', 'completion_length': '39.25', 'kl': '0.6738', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'step_time': '7.209', 'epoch': '0.25'}
# [R0 R-hard] step   18 loss=+0.0115 reward=+1.30
# {'loss': '0.01155', 'grad_norm': '0.6579', 'learning_rate': '3.75e-06', 'num_tokens': '4.577e+04', 'completions/mean_length': '39.12', 'completions/min_length': '37.5', 'completions/max_length': '41', 'completions/clipped_ratio': '0', 'completions/mean_terminated_length': '39.12', 'completions/min_terminated_length': '37.5', 'completions/max_terminated_length': '41', 'rewards/compute_rewards/mean': '1.298', 'rewards/compute_rewards/std': '1.016', 'reward': '1.298', 'reward_std': '1.016', 'frac_reward_zero_std': '0', 'completion_length': '39.12', 'kl': '0.5421', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'step_time': '7.231', 'epoch': '0.2812'}
# [R0 R-hard] step   20 loss=+0.0078 reward=+1.50
# {'loss': '0.007809', 'grad_norm': '0.3233', 'learning_rate': '3.523e-06', 'num_tokens': '5.085e+04', 'completions/mean_length': '38.94', 'completions/min_length': '37.5', 'completions/max_length': '40', 'completions/clipped_ratio': '0', 'completions/mean_terminated_length': '38.94', 'completions/min_terminated_length': '37.5', 'completions/max_terminated_length': '40', 'rewards/compute_rewards/mean': '1.5', 'rewards/compute_rewards/std': '1.986', 'reward': '1.5', 'reward_std': '1.986', 'frac_reward_zero_std': '0', 'completion_length': '38.94', 'kl': '0.5278', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'step_time': '6.936', 'epoch': '0.3125'}
# [rewards] red=R-hard call= 21 parsed=8/8 r_mean=+0.57 top={triage_alerts=5, reconcile_state=3}
# [R0 R-hard] step   22 loss=+0.0166 reward=+1.07
# {'loss': '0.01658', 'grad_norm': '0.5578', 'learning_rate': '3.295e-06', 'num_tokens': '5.594e+04', 'completions/mean_length': '39.06', 'completions/min_length': '38', 'completions/max_length': '39.5', 'completions/clipped_ratio': '0', 'completions/mean_terminated_length': '39.06', 'completions/min_terminated_length': '38', 'completions/max_terminated_length': '39.5', 'rewards/compute_rewards/mean': '1.072', 'rewards/compute_rewards/std': '0.5651', 'reward': '1.072', 'reward_std': '0.5651', 'frac_reward_zero_std': '0', 'completion_length': '39.06', 'kl': '0.5225', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'step_time': '7.022', 'epoch': '0.3438'}
# [R0 R-hard] step   24 loss=+0.0200 reward=+1.64
# {'loss': '0.01998', 'grad_norm': '0.5144', 'learning_rate': '3.068e-06', 'num_tokens': '6.103e+04', 'completions/mean_length': '39.19', 'completions/min_length': '38', 'completions/max_length': '40.5', 'completions/clipped_ratio': '0', 'completions/mean_terminated_length': '39.19', 'completions/min_terminated_length': '38', 'completions/max_terminated_length': '40.5', 'rewards/compute_rewards/mean': '1.642', 'rewards/compute_rewards/std': '1.136', 'reward': '1.642', 'reward_std': '1.136', 'frac_reward_zero_std': '0', 'completion_length': '39.19', 'kl': '0.5332', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'step_time': '7.237', 'epoch': '0.375'}
# [rewards] red=R-hard call= 26 parsed=8/8 r_mean=+1.59 top={triage_alerts=6, harden_policy=1, reconcile_state=1}
# [R0 R-hard] step   26 loss=+0.0070 reward=+1.52
# {'loss': '0.006971', 'grad_norm': '0.4143', 'learning_rate': '2.841e-06', 'num_tokens': '6.613e+04', 'completions/mean_length': '39.31', 'completions/min_length': '38.5', 'completions/max_length': '40.5', 'completions/clipped_ratio': '0', 'completions/mean_terminated_length': '39.31', 'completions/min_terminated_length': '38.5', 'completions/max_terminated_length': '40.5', 'rewards/compute_rewards/mean': '1.517', 'rewards/compute_rewards/std': '0.9204', 'reward': '1.517', 'reward_std': '0.9204', 'frac_reward_zero_std': '0', 'completion_length': '39.31', 'kl': '0.5407', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'step_time': '7.144', 'epoch': '0.4062'}
# [R0 R-hard] step   28 loss=+0.0135 reward=+2.18
# {'loss': '0.0135', 'grad_norm': '0.5242', 'learning_rate': '2.614e-06', 'num_tokens': '7.121e+04', 'completions/mean_length': '38.94', 'completions/min_length': '38', 'completions/max_length': '40', 'completions/clipped_ratio': '0', 'completions/mean_terminated_length': '38.94', 'completions/min_terminated_length': '38', 'completions/max_terminated_length': '40', 'rewards/compute_rewards/mean': '2.18', 'rewards/compute_rewards/std': '1.48', 'reward': '2.18', 'reward_std': '1.48', 'frac_reward_zero_std': '0', 'completion_length': '38.94', 'kl': '0.5471', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'step_time': '7.079', 'epoch': '0.4375'}
# [R0 R-hard] step   30 loss=+0.0193 reward=+1.20
# {'loss': '0.01931', 'grad_norm': '0.5892', 'learning_rate': '2.386e-06', 'num_tokens': '7.63e+04', 'completions/mean_length': '38.88', 'completions/min_length': '37', 'completions/max_length': '39.5', 'completions/clipped_ratio': '0', 'completions/mean_terminated_length': '38.88', 'completions/min_terminated_length': '37', 'completions/max_terminated_length': '39.5', 'rewards/compute_rewards/mean': '1.197', 'rewards/compute_rewards/std': '1.195', 'reward': '1.197', 'reward_std': '1.195', 'frac_reward_zero_std': '0', 'completion_length': '38.88', 'kl': '0.5476', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'step_time': '7.094', 'epoch': '0.4688'}
# [rewards] red=R-hard call= 31 parsed=8/8 r_mean=+1.82 top={triage_alerts=5, query_siem=2, rotate_secrets=1}
# [R0 R-hard] step   32 loss=+0.0173 reward=+1.39
# {'loss': '0.01732', 'grad_norm': '0.4486', 'learning_rate': '2.159e-06', 'num_tokens': '8.138e+04', 'completions/mean_length': '38.62', 'completions/min_length': '37.5', 'completions/max_length': '39.5', 'completions/clipped_ratio': '0', 'completions/mean_terminated_length': '38.62', 'completions/min_terminated_length': '37.5', 'completions/max_terminated_length': '39.5', 'rewards/compute_rewards/mean': '1.392', 'rewards/compute_rewards/std': '1.028', 'reward': '1.392', 'reward_std': '1.028', 'frac_reward_zero_std': '0', 'completion_length': '38.62', 'kl': '0.5591', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'step_time': '6.912', 'epoch': '0.5'}
# [R0 R-hard] step   34 loss=+0.0165 reward=+1.46
# {'loss': '0.01653', 'grad_norm': '0.4937', 'learning_rate': '1.932e-06', 'num_tokens': '8.647e+04', 'completions/mean_length': '38.88', 'completions/min_length': '37', 'completions/max_length': '40', 'completions/clipped_ratio': '0', 'completions/mean_terminated_length': '38.88', 'completions/min_terminated_length': '37', 'completions/max_terminated_length': '40', 'rewards/compute_rewards/mean': '1.462', 'rewards/compute_rewards/std': '0.6374', 'reward': '1.462', 'reward_std': '0.6374', 'frac_reward_zero_std': '0', 'completion_length': '38.88', 'kl': '0.5451', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'step_time': '7.031', 'epoch': '0.5312'}
# [rewards] red=R-hard call= 36 parsed=8/8 r_mean=+1.57 top={triage_alerts=7, rotate_secrets=1}
# [R0 R-hard] step   36 loss=+0.0163 reward=+1.70
# {'loss': '0.01629', 'grad_norm': '0.5676', 'learning_rate': '1.705e-06', 'num_tokens': '9.156e+04', 'completions/mean_length': '39', 'completions/min_length': '38', 'completions/max_length': '40', 'completions/clipped_ratio': '0', 'completions/mean_terminated_length': '39', 'completions/min_terminated_length': '38', 'completions/max_terminated_length': '40', 'rewards/compute_rewards/mean': '1.703', 'rewards/compute_rewards/std': '1.403', 'reward': '1.703', 'reward_std': '1.403', 'frac_reward_zero_std': '0', 'completion_length': '39', 'kl': '0.5706', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'step_time': '7.101', 'epoch': '0.5625'}
# [R0 R-hard] step   38 loss=+0.0162 reward=+1.59
# {'loss': '0.01624', 'grad_norm': '0.5986', 'learning_rate': '1.477e-06', 'num_tokens': '9.664e+04', 'completions/mean_length': '38.75', 'completions/min_length': '37', 'completions/max_length': '40', 'completions/clipped_ratio': '0', 'completions/mean_terminated_length': '38.75', 'completions/min_terminated_length': '37', 'completions/max_terminated_length': '40', 'rewards/compute_rewards/mean': '1.588', 'rewards/compute_rewards/std': '1.211', 'reward': '1.588', 'reward_std': '1.211', 'frac_reward_zero_std': '0', 'completion_length': '38.75', 'kl': '0.5818', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'step_time': '7.108', 'epoch': '0.5938'}
# [R0 R-hard] step   40 loss=+0.0200 reward=+1.68
# {'loss': '0.02', 'grad_norm': '0.6675', 'learning_rate': '1.25e-06', 'num_tokens': '1.017e+05', 'completions/mean_length': '38.69', 'completions/min_length': '37', 'completions/max_length': '39.5', 'completions/clipped_ratio': '0', 'completions/mean_terminated_length': '38.69', 'completions/min_terminated_length': '37', 'completions/max_terminated_length': '39.5', 'rewards/compute_rewards/mean': '1.681', 'rewards/compute_rewards/std': '1.101', 'reward': '1.681', 'reward_std': '1.101', 'frac_reward_zero_std': '0', 'completion_length': '38.69', 'kl': '0.568', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'step_time': '7.303', 'epoch': '0.625'}
# [rewards] red=R-hard call= 41 parsed=8/8 r_mean=+2.20 top={triage_alerts=5, rotate_secrets=1, query_siem=1}
# [R0 R-hard] step   42 loss=+0.0234 reward=+2.13
# {'loss': '0.02341', 'grad_norm': '0.8315', 'learning_rate': '1.023e-06', 'num_tokens': '1.068e+05', 'completions/mean_length': '38.44', 'completions/min_length': '37', 'completions/max_length': '39.5', 'completions/clipped_ratio': '0', 'completions/mean_terminated_length': '38.44', 'completions/min_terminated_length': '37', 'completions/max_terminated_length': '39.5', 'rewards/compute_rewards/mean': '2.134', 'rewards/compute_rewards/std': '1.258', 'reward': '2.134', 'reward_std': '1.258', 'frac_reward_zero_std': '0', 'completion_length': '38.44', 'kl': '0.5952', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'step_time': '7.356', 'epoch': '0.6562'}
# [R0 R-hard] step   44 loss=+0.0140 reward=+1.11
# {'loss': '0.01398', 'grad_norm': '0.6666', 'learning_rate': '7.955e-07', 'num_tokens': '1.119e+05', 'completions/mean_length': '39.12', 'completions/min_length': '38.5', 'completions/max_length': '40', 'completions/clipped_ratio': '0', 'completions/mean_terminated_length': '39.12', 'completions/min_terminated_length': '38.5', 'completions/max_terminated_length': '40', 'rewards/compute_rewards/mean': '1.111', 'rewards/compute_rewards/std': '0.8388', 'reward': '1.111', 'reward_std': '0.8388', 'frac_reward_zero_std': '0', 'completion_length': '39.12', 'kl': '0.5504', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'step_time': '7.035', 'epoch': '0.6875'}
# [rewards] red=R-hard call= 46 parsed=8/8 r_mean=+1.15 top={triage_alerts=8}
# [R0 R-hard] step   46 loss=+0.0079 reward=+1.30
# {'loss': '0.007871', 'grad_norm': '0.1486', 'learning_rate': '5.682e-07', 'num_tokens': '1.17e+05', 'completions/mean_length': '39.06', 'completions/min_length': '39', 'completions/max_length': '39.5', 'completions/clipped_ratio': '0', 'completions/mean_terminated_length': '39.06', 'completions/min_terminated_length': '39', 'completions/max_terminated_length': '39.5', 'rewards/compute_rewards/mean': '1.298', 'rewards/compute_rewards/std': '0.8103', 'reward': '1.298', 'reward_std': '0.8103', 'frac_reward_zero_std': '0', 'completion_length': '39.06', 'kl': '0.5398', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'step_time': '6.934', 'epoch': '0.7188'}
# [R0 R-hard] step   48 loss=+0.0164 reward=+1.26
# {'loss': '0.01641', 'grad_norm': '0.3473', 'learning_rate': '3.409e-07', 'num_tokens': '1.221e+05', 'completions/mean_length': '38.94', 'completions/min_length': '38', 'completions/max_length': '40', 'completions/clipped_ratio': '0', 'completions/mean_terminated_length': '38.94', 'completions/min_terminated_length': '38', 'completions/max_terminated_length': '40', 'rewards/compute_rewards/mean': '1.259', 'rewards/compute_rewards/std': '0.8735', 'reward': '1.259', 'reward_std': '0.8735', 'frac_reward_zero_std': '0', 'completion_length': '38.94', 'kl': '0.5389', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'step_time': '7.217', 'epoch': '0.75'}
# [R0 R-hard] step   50 loss=+0.0177 reward=+1.51
# {'loss': '0.0177', 'grad_norm': '0.5183', 'learning_rate': '1.136e-07', 'num_tokens': '1.272e+05', 'completions/mean_length': '38.88', 'completions/min_length': '38', 'completions/max_length': '40', 'completions/clipped_ratio': '0', 'completions/mean_terminated_length': '38.88', 'completions/min_terminated_length': '38', 'completions/max_terminated_length': '40', 'rewards/compute_rewards/mean': '1.509', 'rewards/compute_rewards/std': '1.007', 'reward': '1.509', 'reward_std': '1.007', 'frac_reward_zero_std': '0', 'completion_length': '38.88', 'kl': '0.5485', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'step_time': '7.178', 'epoch': '0.7812'}
# {'train_runtime': '362.6', 'train_samples_per_second': '1.103', 'train_steps_per_second': '0.138', 'train_loss': '0.01461', 'epoch': '0.7812'}
#   Heuristic payoffs (easy/mid/hard) = [5.475, -0.35, 0.9]
#   PSRO meta-probs  = [0.564, 0.176, 0.259]
#   Pool win-rates: [('R-easy', 0.2), ('R-mid', 0.5), ('R-hard', 0.23)]
# Saved round plot -> /content/outputs_cyber/round_0_R-hard_final.png
#
# Wrote /content/outputs_cyber/league_log.json, /content/outputs_cyber/log_history_combined.json, /content/outputs_cyber/league_state.jsonl
# Saved -> /content/outputs_cyber/grpo_r0_R-hard/training_curves.png and /content/outputs_cyber/grpo_r0_R-hard/log_history.json
# Saved -> /content/outputs_cyber/training_curves_all_rounds.png
#
# Saved LoRA adapter to /content/outputs_cyber/cyber-blue-grpo-lora
# [push] skipped -- set HF_TOKEN as a Kaggle Secret to enable.
#
# ===== Post-GRPO sanity check =====
#
# --- sample 1 (parse_ok=True) ---
# {"actor": "blue", "tool_name": "triage_alerts", "target": "host-05", "params": {}, "rationale": "investigate alert"}
# Parsed: {'actor': 'blue', 'tool_name': 'triage_alerts', 'target': 'host-05', 'params': {}, 'rationale': 'investigate alert'}
#
# --- sample 2 (parse_ok=True) ---
# {"actor": "blue", "tool_name": "triage_alerts", "target": "host-05", "params": {}, "rationale": "investigate alert"}
# Parsed: {'actor': 'blue', 'tool_name': 'triage_alerts', 'target': 'host-05', 'params': {}, 'rationale': 'investigate alert'}
#
# --- sample 3 (parse_ok=True) ---
# {"actor": "blue", "tool_name": "triage_alerts", "target": "host-05", "params": {}, "rationale": "investigate alert"}
# Parsed: {'actor': 'blue', 'tool_name': 'triage_alerts', 'target': 'host-05', 'params': {}, 'rationale': 'investigate alert'}
#
# Done.
